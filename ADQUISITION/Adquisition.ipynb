# %% [markdown]
# AQUI SOLO VAMOS A METER LOS DATOS DE ADQUISITION:
# Es decir es el paso donde nosotros pillamos las tablas de las bases de datos, en el caso de este proyecto, tenemos dos tablas:
#
# - tabla de bicimad_stations(es la que tenemos comun para todos, y donde estan todas las estaciones de bicimad de madrid)
# - tabla de Sedes.Centros deportivos( es la tabla que me ha tocado a mi y de la cual posteriormente sacaremos las direcciones para saber cual es la estacion de bicimad mas cercana)

# %%
#LO PRIMERO DE TODO CUANDO EMPEZAMOS UN LIBRO NUEVO ES IMPORTAR TODAS LAS LIBRERIAS QUE CREEMOS QUE VAMOS A USAR:

import pandas as pd 
import numpy as np
import requests
import json
from bs4 import BeautifulSoup 
import os

# %%
#VAMOS A IMPORTARNOS/ADQUIRIR LA TABLA DONDE TENEOMOS TODAS LAS ESTACIONES DE BICIMAD:

os.listdir("../ih_datamadpt1121_project_m1/DATA")  #super util este metodo para saber la ruta relativa de donde tenemos guardado el archivo.

dataframe_bicimadstations = pd.read_json("../ih_datamadpt1121_project_m1/DATA/bicimad_stations.json")
dataframe_bicimadstations
# Out:
#       id                    name  light number  \
# 0      1        Puerta del Sol A      2     1a
# 1      2        Puerta del Sol B      1     1b
# 2      3             Miguel Moya      2      2
# 3      4      Plaza Conde Suchil      0      3
# 4      5                Malasaña      2      4
# ..   ...                     ...    ...    ...
# 259  266  Ciudad Universitaria 1      0    258
# 260  267  Ciudad Universitaria 2      2    259
# 261  268       Facultad Biología      2    260
# 262  269        Facultad Derecho      0    261
# 263  270                 Zurbano      0    247
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ...

# %%
#VAMOS A IMPORTARNOS/ADQUIRIR LA TABLA DONDE TENEOMOS TODAS LAS DIRECCIONES(de sedes y centros deportivos)DE LAS QUE QUEREMOS SABER LAS ESTACIONES DE BICIMAD MAS CERCANAS:


os.listdir("../ih_datamadpt1121_project_m1/DATA")  #super util este metodo para saber la ruta relativa de donde tenemos guardado el archivo.

dataframe_centrosdeportivos = pd.read_csv("../ih_datamadpt1121_project_m1/DATA/212808-0-espacio-deporte.csv", delimiter = ";")
dataframe_centrosdeportivos
# Out:
#            PK                                             NOMBRE  \
# 0      181447          Campo de Golf del Centro Nacional de Golf
# 1        4670  Campo de Golf del Club de Golf Olivar de la Hi...
# 2       56494                Campos de Fútbol Ernesto Cotorruelo
# 3     7381184  Centro Comercial Dreams - Palacio Municipal de...
# 4     7081762  Centro de Alto Rendimiento del Consejo Superio...
# ..        ...                                                ...
# 606   5860245                               Piscina SAGE Fitness
# 607  10967954                    Pista de Patinaje Paco de Lucía
# 608  10967959      Pista de petanca Centro de Mayores La Vaguada
# 609      4731                    Polideportivo Antonio Magariños
# 610    165847                                      WiZink Center
#
#                                  DESCRIPCION-ENTIDAD HORARIO  \
# 0                                                NaN     NaN
# ...

# %%
#HASTA AQUI LO UNICO QUE TENIAMOS QUE HACER ERA IMPORTAR LAS TABLAS POR LO QUE EL TRABAJO EN ESTE APARTADO YA ESTA HECHO.
